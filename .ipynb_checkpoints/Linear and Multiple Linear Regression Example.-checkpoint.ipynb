# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/gabrieldelao/anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/gabrieldelao/anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
data.shape
# Out:
# (200, 4)

# %%
fig, axs = plt.subplots(1,3, sharey=True)
data.plot(kind='scatter', x = 'TV', y='Sales', ax=axs[0], figsize=(16,8))
data.plot(kind='scatter', x = 'Radio', y='Sales', ax=axs[1])
data.plot(kind='scatter', x = 'TV', y='Sales', ax=axs[2])

# %%
import statsmodels.formula.api as smf

# fitted model.
lm = smf.ols(formula='Sales ~ TV', data=data ).fit()

print(lm.params)
print( lm.summary() )
# Out:
# Intercept    7.032594
# TV           0.047537
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Fri, 20 May 2016   Prob (F-statistic):           1.47e-42
# Time:                        14:38:18   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000         6.130     7.935
# TV             0.0475      0.003     17.668      0.000         0.042     0.053
# ==============================================================================
# Omnibus:                        0.531   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.669
# Skew:                          -0.089   Prob(JB):                        0.716
# Kurtosis:                       2.779   Cond. No.                         338.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# manually. 50,000 extra spending on TV.
7.032594 + 0.047537 * 50

# using statsmodel
X_new = pd.DataFrame({'TV':[50]})
X_new.head()
lm.predict(X_new)
# Out:
# array([ 9.40942557])

# %%
lm.predict(X_new)
# Out:
# array([ 9.40942557])

# %%
# least squares.
X_new = pd.DataFrame({'TV': [data.TV.min(), data.TV.max()]})
X_new.head()
# Out:
#       TV
# 0    0.7
# 1  296.4

# %%
preds = lm.predict(X_new)
preds
# Out:
# array([  7.0658692 ,  21.12245377])

# %%
# plot of the observed data
data.plot(kind='scatter', x="TV", y='Sales')
plt.plot(X_new, preds, c='red', linewidth=2)

# %%
# confidence intervals for the model coefficients.
lm.conf_int()
# Out:
#                   0         1
# Intercept  6.129719  7.935468
# TV         0.042231  0.052843

# %%
# p values for the model coefficients
lm.pvalues
# Out:
# Intercept    1.406300e-35
# TV           1.467390e-42
# dtype: float64

# %%
lm.rsquared
# Out:
# 0.61187505085007099

# %%
# Multiple Linear Regression
